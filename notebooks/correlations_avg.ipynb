# %%
import numpy as np
import os
from os.path import join as joinpath
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
FIRST_DIM_TARGET_SIZE = 10

def compute_correlation_from_activity_matrix(activity_matrix):
    if activity_matrix.shape[0] != FIRST_DIM_TARGET_SIZE:
        activity_matrix = activity_matrix[0]
    # ensure activity_matrix is a 2D array
    activity_matrix = activity_matrix.reshape(activity_matrix.shape[0], -1)
    # compute correlation score for matrix of shape [T, N_NEURONS]
    corr_matrix = np.corrcoef(activity_matrix.T)
    corr_matrix[np.isnan(corr_matrix)] = 0
    return corr_matrix

# %%
def compute_average_layer_correlation_scores(root_data_path : str, save_path : str = None):
    layer_correlations_correct = {}
    layer_correlations_incorrect = {}
    global_sample_count = 0
    for  label_dir in os.listdir(root_data_path):
        # label level
        print(f"Label: {label_dir}")
        label_dir_path = joinpath(root_data_path, label_dir)
        if not os.path.isdir(label_dir_path):
            continue
        # sample level
        if label_dir == "label_3":
            # skip label 3, as full noise samples result in predicting label 3
            continue
        for num_samples, sample_dir in enumerate(os.listdir(label_dir_path)):
            if num_samples >= 2:
                global_sample_count += num_samples + 1
                break
            print(f"Sample {num_samples + 1} ")
            sample_dir_path = joinpath(label_dir_path, sample_dir)
            if not os.path.isdir(sample_dir_path):
                continue
            
            original_actiities_dir = joinpath(sample_dir_path, 'correct_original')
            incorrect_noise_activities_dir = [joinpath(sample_dir_path, f) 
                                                for f in os.listdir(sample_dir_path)
                                                if 'incorrect' in f and 'noise' in f][0]
            correct_layer_activity_files = [joinpath(original_actiities_dir, f) 
                                            for f in os.listdir(original_actiities_dir)
                                            if 'spike' in f]
            for layer_activity in correct_layer_activity_files:
                layer_name, layer_num = layer_activity.split('_')[-2:]
                layer_num = layer_num.split('.')[0] 
                layer_name = f"{layer_name}_{layer_num}"
                corr_matrix = compute_correlation_from_activity_matrix(np.load(layer_activity))
                if layer_name not in layer_correlations_correct:
                    layer_correlations_correct[layer_name] = corr_matrix
                else:
                    layer_correlations_correct[layer_name] += corr_matrix

            incorrect_layer_activity_files = [joinpath(incorrect_noise_activities_dir, f) 
                                                for f in os.listdir(incorrect_noise_activities_dir)
                                                if 'spike' in f]
            for layer_activity in incorrect_layer_activity_files:
                layer_name, layer_num = layer_activity.split('_')[-2:]
                layer_num = layer_num.split('.')[0] 
                layer_name = f"{layer_name}_{layer_num}"
                corr_matrix = compute_correlation_from_activity_matrix(np.load(layer_activity))
                if layer_name not in layer_correlations_incorrect:
                    layer_correlations_incorrect[layer_name] = corr_matrix
                else:
                    layer_correlations_incorrect[layer_name] += corr_matrix


    # average the correlation scores and save them to npy arrays
    for layer_name in layer_correlations_correct:
        layer_correlations_correct[layer_name] /= num_samples
        
    for layer_name in layer_correlations_incorrect:
        layer_correlations_incorrect[layer_name] /= num_samples

    return layer_correlations_correct, layer_correlations_incorrect

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join as joinpath
from scipy.stats import kurtosis, skew

corr_results_dir = "/home/szymon/code/PhD/snns_adversarial_benchmark/avg_corr_results_CIFAR10_simple_mlp_snn"
files_list = os.listdir(corr_results_dir)

layer_names_raw = [f.split('_')[0] + "_" + f.split('_')[1] for f in files_list if ".npy" in f]
layer_names_unique_sorted = sorted(list(dict.fromkeys(layer_names_raw)), key=lambda x: int(x.split('_')[1]))

layers_to_plot = layer_names_unique_sorted
num_rows = len(layers_to_plot)

if num_rows == 0:
    print("No layers to plot after the 10th layer.")
else:
    fig, axs = plt.subplots(num_rows, 4, figsize=(22, 5 * num_rows))

    if num_rows == 1:
        axs = axs[np.newaxis, :]

    for i, layer_name in enumerate(layers_to_plot):
        correct_corr_path = joinpath(corr_results_dir, f"{layer_name}_correct_avg_correlation.npy")
        incorrect_corr_path = joinpath(corr_results_dir, f"{layer_name}_incorrect_avg_correlation.npy")

        if not os.path.exists(correct_corr_path) or not os.path.exists(incorrect_corr_path):
            print(f"Skipping {layer_name}: Correlation files not found.")
            continue

        correct_corr = np.load(correct_corr_path)
        incorrect_corr = np.load(incorrect_corr_path)

        # Flatten the arrays for distribution analysis
        correct_flat = correct_corr.flatten()
        incorrect_flat = incorrect_corr.flatten()

        # --- Quantify "super high" values ---
        # Using 99th percentile as a threshold
        percentile_threshold = 99
        correct_99th_percentile = np.percentile(correct_flat, percentile_threshold)
        incorrect_99th_percentile = np.percentile(incorrect_flat, percentile_threshold)

        # Count values above this percentile (for correct > correct_99th_percentile and incorrect > incorrect_99th_percentile)
        num_above_correct_thresh = np.sum(correct_flat > correct_99th_percentile)
        num_above_incorrect_thresh = np.sum(incorrect_flat > incorrect_99th_percentile)

        # Alternatively, count values above a fixed high threshold (e.g., 0.9)
        fixed_high_threshold = 0.9
        num_correct_gt_fixed = np.sum(correct_flat > fixed_high_threshold)
        num_incorrect_gt_fixed = np.sum(incorrect_flat > fixed_high_threshold)

        # --- Quantify sharpness (Kurtosis) and asymmetry (Skewness) ---
        kurt_correct = kurtosis(correct_flat)
        kurt_incorrect = kurtosis(incorrect_flat)

        skew_correct = skew(correct_flat)
        skew_incorrect = skew(incorrect_flat)

        # --- Plotting ---
        fontsize_annotations = 10
        
        # Correct Correlation Matrix
        sns.heatmap(correct_corr, ax=axs[i, 0], cmap='viridis', cbar=True, vmin=-1, vmax=1)
        axs[i, 0].set_title(f'Corr. matrix, no noise - {layer_name}')
        axs[i, 0].set_aspect('equal', adjustable='box')

        # Incorrect Correlation Matrix
        sns.heatmap(incorrect_corr, ax=axs[i, 1], cmap='viridis', cbar=True, vmin=-1, vmax=1)
        axs[i, 1].set_title(f'Corr. matrix, noise - {layer_name}')
        axs[i, 1].set_aspect('equal', adjustable='box')

        # Plot Distribution of Correct Correlation Values
        sns.histplot(correct_flat, ax=axs[i, 2], kde=True, color='skyblue', bins=50)
        axs[i, 2].set_title(f'Corr. distribtuion, no noise - {layer_name}')
        axs[i, 2].set_xlabel('Correlation Value')
        axs[i, 2].set_ylabel('Density')
        # Add statistics to the plot
        axs[i, 2].text(0.7, 0.95, f'Kurtosis: {kurt_correct:.2f}', transform=axs[i, 2].transAxes, fontsize=fontsize_annotations, verticalalignment='top')
        axs[i, 2].text(0.7, 0.90, f'Skewness: {skew_correct:.2f}', transform=axs[i, 2].transAxes, fontsize=fontsize_annotations, verticalalignment='top')
        axs[i, 2].text(0.7, 0.85, f'99th Pctile: {correct_99th_percentile:.2f}', transform=axs[i, 2].transAxes, fontsize=fontsize_annotations, verticalalignment='top')
        axs[i, 2].text(0.7, 0.80, f'Values > {fixed_high_threshold}: {num_correct_gt_fixed}', transform=axs[i, 2].transAxes, fontsize=fontsize_annotations, verticalalignment='top')

        # Plot Distribution of Incorrect Correlation Values
        sns.histplot(incorrect_flat, ax=axs[i, 3], kde=True, color='salmon', bins=50)
        axs[i, 3].set_title(f'Corr. distribution, noise - {layer_name}')
        axs[i, 3].set_xlabel('Correlation Value')
        axs[i, 3].set_ylabel('Density')
        # Add statistics to the plot
        axs[i, 3].text(0.7, 0.95, f'Kurtosis: {kurt_incorrect:.2f}', transform=axs[i, 3].transAxes, fontsize=fontsize_annotations, verticalalignment='top')
        axs[i, 3].text(0.7, 0.90, f'Skewness: {skew_incorrect:.2f}', transform=axs[i, 3].transAxes, fontsize=fontsize_annotations, verticalalignment='top')
        axs[i, 3].text(0.7, 0.85, f'99th Pctile: {incorrect_99th_percentile:.2f}', transform=axs[i, 3].transAxes, fontsize=fontsize_annotations, verticalalignment='top')
        axs[i, 3].text(0.7, 0.80, f'Values > {fixed_high_threshold}: {num_incorrect_gt_fixed}', transform=axs[i, 3].transAxes, fontsize=fontsize_annotations, verticalalignment='top')


        print(f"Layer {layer_name} plotted")
        print(f"  Correct: Kurtosis={kurt_correct:.2f}, Skewness={skew_correct:.2f}, 99th Pctile={correct_99th_percentile:.2f}, Count > {fixed_high_threshold}={num_correct_gt_fixed}")
        print(f"  Incorrect: Kurtosis={kurt_incorrect:.2f}, Skewness={skew_incorrect:.2f}, 99th Pctile={incorrect_99th_percentile:.2f}, Count > {fixed_high_threshold}={num_incorrect_gt_fixed}\n")

        
    plt.tight_layout()
    plt.show()

# %%
corr_results_dir = "/home/szymon/code/PhD/snns_adversarial_benchmark/avg_corr_results_MNIST_simple_mlp_snn"
files_list = os.listdir(corr_results_dir)
layer_names = [f.split('_')[0] + "_" + f.split('_')[1] for f in files_list]
fig, axs = plt.subplots(len(layer_names), 2, figsize=(10, 5 * len(layer_names)))
layer_names = sorted(layer_names, key=lambda x: int(x.split('_')[1]))
# take only unique layer names
layer_names = list(dict.fromkeys(layer_names))
for i,layer_name in enumerate(layer_names[10:]):
    correct_corr = np.load(joinpath(corr_results_dir, f"{layer_name}_correct_avg_correlation.npy"))
    incorrect_corr = np.load(joinpath(corr_results_dir, f"{layer_name}_incorrect_avg_correlation.npy"))
    sns.heatmap(correct_corr, ax=axs[i, 0],

                    cmap='viridis', cbar=True, vmin=-1, vmax=1)
    axs[i, 0].set_title(f'Correct Layer Correlation - {layer_name}')
    sns.heatmap(incorrect_corr, ax=axs[i, 1],
                    cmap='viridis', cbar=True, vmin=-1, vmax=1)
    axs[i, 1].set_title(f'Incorrect Layer Correlation - {layer_name}')
    print(f"Layer {layer_name} plotted")

# %%
corr_results_dir = "/home/szymon/code/PhD/snns_adversarial_benchmark/avg_corr_results_avg_sampling_100"
files_list = os.listdir(corr_results_dir)
layer_names = [f.split('_')[0] + "_" + f.split('_')[1] for f in files_list]
fig, axs = plt.subplots(len(layer_names[10:]), 2, figsize=(10, 5 * len(layer_names)))
layer_names = sorted(layer_names, key=lambda x: int(x.split('_')[1]))
# take only unique layer names
layer_names = list(dict.fromkeys(layer_names))
for i,layer_name in enumerate(layer_names[10:]):
    correct_corr = np.load(joinpath(corr_results_dir, f"{layer_name}_correct_avg_correlation.npy"))
    incorrect_corr = np.load(joinpath(corr_results_dir, f"{layer_name}_incorrect_avg_correlation.npy"))
    sns.heatmap(correct_corr, ax=axs[i, 0],

                    cmap='viridis', cbar=True, vmin=-1, vmax=1)
    axs[i, 0].set_title(f'Correct Layer Correlation - {layer_name}')
    sns.heatmap(incorrect_corr, ax=axs[i, 1],
                    cmap='viridis', cbar=True, vmin=-1, vmax=1)
    axs[i, 1].set_title(f'Incorrect Layer Correlation - {layer_name}')
    print(f"Layer {layer_name} plotted")
