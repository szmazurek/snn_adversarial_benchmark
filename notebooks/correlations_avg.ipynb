# %%
import numpy as np
import os
from os.path import join as joinpath
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
FIRST_DIM_TARGET_SIZE = 10

def compute_correlation_from_activity_matrix(activity_matrix):
    if activity_matrix.shape[0] != FIRST_DIM_TARGET_SIZE:
        activity_matrix = activity_matrix[0]
    # ensure activity_matrix is a 2D array
    activity_matrix = activity_matrix.reshape(activity_matrix.shape[0], -1)
    # compute correlation score for matrix of shape [T, N_NEURONS]
    corr_matrix = np.corrcoef(activity_matrix.T)
    corr_matrix[np.isnan(corr_matrix)] = 0
    return corr_matrix

# %%
from skimage.measure import block_reduce
from scipy.ndimage import zoom

def downsample_matrix(matrix, max_size=500):
    """
    Downsample a correlation matrix to a maximum size while preserving structure.

    Args:
        matrix (np.ndarray): Input correlation matrix
        max_size (int): Maximum dimension for the downsampled matrix

    Returns:
        np.ndarray: Downsampled matrix
    """
    if matrix.shape[0] <= max_size and matrix.shape[1] <= max_size:
        return matrix

    # Calculate zoom factor
    zoom_factor = min(max_size / matrix.shape[0], max_size / matrix.shape[1])

    # Downsample using scipy.ndimage.zoom with cubic interpolation
    downsampled = zoom(matrix, zoom_factor, order=3, mode="nearest")

    return downsampled

# %%
import os
import string
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join as joinpath
from scipy.stats import kurtosis, skew

def plot_correlation_matrices_and_distributions(exp_name: str):
    """
    Plots correlation matrices and their value distributions for different layers,
    comparing a 'no noise' (correct) and 'noise' (incorrect) condition.

    Args:
        exp_name (str): The name of the experiment, used to locate data files.

    Returns:
        tuple: A tuple containing two dictionaries with statistics for the last plotted layer:
               (correct_stats_dict, incorrect_stats_dict), or (None, None) if no data is found.
    """
    # --- Configuration Variables ---
    fontsize_ticks = 14
    fontsize_annotations = 16
    fontsize_axis_labels = 16
    tick_divisor = 5  # Used to create sparser ticks on heatmaps

    # --- Data Loading and Preparation ---
    corr_results_dir = f"/home/szymon/code/PhD/snns_adversarial_benchmark/{exp_name}"
    files_list = os.listdir(corr_results_dir)

    layer_names_raw = [f.split('_')[0] + "_" + f.split('_')[1] for f in files_list if ".npy" in f]
    layer_names_unique_sorted = sorted(list(dict.fromkeys(layer_names_raw)), key=lambda x: int(x.split('_')[1]))

    layers_to_plot = layer_names_unique_sorted
    num_layers = len(layers_to_plot)

    if num_layers == 0:
        print("No layers to plot.")
        return None, None

    # --- Plotting Setup ---
    fig, axs = plt.subplots(num_layers * 2, 2, figsize=(20, 10 * num_layers))

    if axs.ndim == 1:
        axs = axs.reshape(-1, 2) if num_layers * 2 > 1 else axs.reshape(1, -1)

    subplot_labels = [f"{char})" for char in string.ascii_uppercase]
    label_idx = 0

    # --- Main Plotting Loop ---
    for i, layer_name in enumerate(layers_to_plot):
        correct_corr_path = joinpath(corr_results_dir, f"{layer_name}_correct_avg_correlation.npy")
        incorrect_corr_path = joinpath(corr_results_dir, f"{layer_name}_incorrect_avg_correlation.npy")

        if not os.path.exists(correct_corr_path) or not os.path.exists(incorrect_corr_path):
            print(f"Skipping {layer_name}: Correlation files not found.")
            for j in range(2):
                axs[2*i, j].axis('off')
                axs[2*i+1, j].axis('off')
            continue

        correct_corr = np.load(correct_corr_path)
        incorrect_corr = np.load(incorrect_corr_path)
        decimated_size = 512
        correct_corr_decimated = downsample_matrix(correct_corr, max_size=decimated_size)
        incorrect_corr_decimated = downsample_matrix(incorrect_corr, max_size=decimated_size)
        print(f"Layer: {layer_name}, Original Size: {correct_corr.shape[0]}, Decimated Size: {correct_corr_decimated.shape[0]}")
        
        correct_flat = correct_corr.flatten()
        incorrect_flat = incorrect_corr.flatten()

        # --- Statistical Calculations ---
        percentile_threshold = 99
        correct_99th_percentile = np.percentile(correct_flat, percentile_threshold)
        incorrect_99th_percentile = np.percentile(incorrect_flat, percentile_threshold)
        num_correct_above_p99 = np.sum(correct_flat > correct_99th_percentile)
        num_incorrect_above_p99 = np.sum(incorrect_flat > incorrect_99th_percentile)
        fixed_high_threshold_4th_percentile = 0.75
        fixed_high_threshold_last_decile = 0.9
        num_correct_gt_fixed = np.sum(correct_flat > fixed_high_threshold_4th_percentile)
        num_incorrect_gt_fixed = np.sum(incorrect_flat > fixed_high_threshold_4th_percentile)
        num_correct_gt_fixed_last_decile = np.sum(correct_flat > fixed_high_threshold_last_decile)
        num_incorrect_gt_fixed_last_decile = np.sum(incorrect_flat > fixed_high_threshold_last_decile)
        kurt_correct, kurt_incorrect = kurtosis(correct_flat), kurtosis(incorrect_flat)
        skew_correct, skew_incorrect = skew(correct_flat), skew(incorrect_flat)
        mean_correct, mean_incorrect = np.mean(correct_flat) * 1e3, np.mean(incorrect_flat) * 1e3
        median_correct, median_incorrect = np.median(correct_flat) * 1e3, np.median(incorrect_flat) * 1e3
        
        # ADDITION: Calculate standard deviation
        std_correct = np.std(correct_flat) * 1e3
        std_incorrect = np.std(incorrect_flat) * 1e3

        # --- Plotting for the current layer ---
        row_correct = 2 * i
        row_incorrect = 2 * i + 1

        # -- Row 1: No Noise (Correct) --
        ax_corr_correct = axs[row_correct, 0]
        ax_dist_correct = axs[row_correct, 1]
        
        sns.heatmap(correct_corr_decimated, ax=ax_corr_correct, cmap='viridis', cbar=True, vmin=-1, vmax=1)
        cbar_correct = ax_corr_correct.collections[0].colorbar
        cbar_correct.ax.tick_params(labelsize=fontsize_ticks)
        
        ax_corr_correct.set_aspect('equal', adjustable='box')
        ax_corr_correct.text(-0.15, 1.1, subplot_labels[label_idx], transform=ax_corr_correct.transAxes, fontsize=18, va='top', ha='right', fontweight='bold')
        label_idx += 1
        
        sns.histplot(correct_flat, ax=ax_dist_correct, kde=True, color='skyblue', bins=50)
        # ADDITION: Add std dev to the text
        stats_text = (f'Mean (scaled): {mean_correct:.2f}\n'
                      f'Median (scaled): {median_correct:.2f}\n'
                      f'Std Dev (scaled): {std_correct:.2f}\n'
                      f'Kurtosis: {kurt_correct:.2f}\n'
                      f'Skewness: {skew_correct:.2f}\n'
                      f'99th Pctile: {correct_99th_percentile:.2f}\n'
                      f'Count > {fixed_high_threshold_4th_percentile}: {num_correct_gt_fixed}\n'
                      f'Count > {fixed_high_threshold_last_decile}: {num_correct_gt_fixed_last_decile}')
        ax_dist_correct.text(0.65, 0.95, stats_text, transform=ax_dist_correct.transAxes, fontsize=fontsize_annotations, verticalalignment='top')
        ax_dist_correct.text(-0.15, 1.1, subplot_labels[label_idx], transform=ax_dist_correct.transAxes, fontsize=18, va='top', ha='right', fontweight='bold')
        label_idx += 1

        # -- Row 2: Noise (Incorrect) --
        ax_corr_incorrect = axs[row_incorrect, 0]
        ax_dist_incorrect = axs[row_incorrect, 1]

        sns.heatmap(incorrect_corr_decimated, ax=ax_corr_incorrect, cmap='viridis', cbar=True, vmin=-1, vmax=1)
        cbar_incorrect = ax_corr_incorrect.collections[0].colorbar
        cbar_incorrect.ax.tick_params(labelsize=fontsize_ticks)

        ax_corr_incorrect.set_aspect('equal', adjustable='box')
        ax_corr_incorrect.text(-0.15, 1.1, subplot_labels[label_idx], transform=ax_corr_incorrect.transAxes, fontsize=18, va='top', ha='right', fontweight='bold')
        label_idx += 1
        
        sns.histplot(incorrect_flat, ax=ax_dist_incorrect, kde=True, color='salmon', bins=50)
        # ADDITION: Add std dev to the text
        stats_text = (f'Mean (scaled): {mean_incorrect:.2f}\n'
                      f'Median (scaled): {median_incorrect:.2f}\n'
                      f'Std Dev (scaled): {std_incorrect:.2f}\n'
                      f'Kurtosis: {kurt_incorrect:.2f}\n'
                      f'Skewness: {skew_incorrect:.2f}\n'
                      f'99th Pctile: {incorrect_99th_percentile:.2f}\n'
                      f'Count > {fixed_high_threshold_4th_percentile}: {num_incorrect_gt_fixed}\n'
                      f'Count > {fixed_high_threshold_last_decile}: {num_incorrect_gt_fixed_last_decile}')
        ax_dist_incorrect.text(0.65, 0.95, stats_text, transform=ax_dist_incorrect.transAxes, fontsize=fontsize_annotations, verticalalignment='top')
        ax_dist_incorrect.text(-0.15, 1.1, subplot_labels[label_idx], transform=ax_dist_incorrect.transAxes, fontsize=18, va='top', ha='right', fontweight='bold')
        label_idx += 1
        
        # --- Apply Formatting ---
        for ax in [ax_dist_correct, ax_dist_incorrect]:
            ax.set_xlabel('Correlation Value', fontsize=fontsize_axis_labels)
            ax.set_ylabel('Density', fontsize=fontsize_axis_labels)
            ax.ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))
        for ax in [ax_corr_correct, ax_dist_correct, ax_corr_incorrect, ax_dist_incorrect]:
            ax.tick_params(axis='both', which='major', labelsize=fontsize_ticks)

        for ax, corr_matrix in zip([ax_corr_correct, ax_corr_incorrect], [correct_corr_decimated, incorrect_corr_decimated]):
            N = corr_matrix.shape[0]
            tick_spacing = max(1, N // tick_divisor)
            ticks = np.arange(0, N, tick_spacing)
            ax.set_xticks(ticks)
            ax.set_yticks(ticks)
            ax.set_xticklabels(ticks.astype(int))
            ax.set_yticklabels(ticks.astype(int))

    # --- Finalization ---
    # ADDITION: Add std_dev to the dictionaries
    correct_stats_dict = {
        "mean": float(mean_correct),
        "median": float(median_correct),
        "std_dev": float(std_correct),
        "kurtosis": float(kurt_correct),
        "skewness": float(skew_correct),
        "99th_percentile": float(correct_99th_percentile),
        "count_above_90": int(num_correct_gt_fixed_last_decile)
    }
    incorrect_stats_dict = {
        "mean": float(mean_incorrect),
        "median": float(median_incorrect),
        "std_dev": float(std_incorrect),
        "kurtosis": float(kurt_incorrect),
        "skewness": float(skew_incorrect),
        "99th_percentile": float(incorrect_99th_percentile),
        "count_above_90": int(num_incorrect_gt_fixed_last_decile)
    }
    
    plt.tight_layout(pad=3.0)
    plt.savefig(f"../../figures/{exp_name}.pdf", bbox_inches='tight', dpi=350)
    print(f"Saved figure for experiment: {exp_name}")
    plt.show()

    return correct_stats_dict, incorrect_stats_dict

# %%
datasets = ["EventMNIST", "CIFAR10", "MNIST"]
# network_types = ["mlp","conv"]
correct_stats_all = {}
incorrect_stats_all = {}
exp_names = [dirname for dirname in os.listdir('/home/szymon/code/PhD/snns_adversarial_benchmark/') if "sew" in dirname]
for exp_name in exp_names:
    stats_correct, stats_incorrect = plot_correlation_matrices_and_distributions(exp_name)
    correct_stats_all[exp_name] = stats_correct
    incorrect_stats_all[exp_name] = stats_incorrect
    # recurrent_exp_name = f"{exp_name}_recurrent"
    # stats_correct_recurrent, stats_incorrect_recurrent = plot_correlation_matrices_and_distributions(recurrent_exp_name)
    # correct_stats_all[recurrent_exp_name] = stats_correct_recurrent
    # incorrect_stats_all[recurrent_exp_name] = stats_incorrect_recurrent
# save json
import json
with open('../../stats/correlation_stats_correct.json', 'w') as f:
    json.dump(correct_stats_all, f, indent=4)
with open('../../stats/correlation_stats_incorrect.json', 'w') as f:
    json.dump(incorrect_stats_all, f, indent=4)
# Out:
# Layer: layer_19, Original Size: 512, Decimated Size: 512
# Saved figure for experiment: avg_corr_results_MNIST_sew_resnet
# Layer: layer_19, Original Size: 512, Decimated Size: 512
# Saved figure for experiment: avg_corr_results_CIFAR10_sew_resnet
# Layer: layer_19, Original Size: 2048, Decimated Size: 512
# Saved figure for experiment: avg_corr_results_EventMNIST_sew_resnet

# %%
corr_results_dir = "/home/szymon/code/PhD/snns_adversarial_benchmark/avg_corr_results_MNIST_simple_mlp_snn"
files_list = os.listdir(corr_results_dir)
layer_names = [f.split('_')[0] + "_" + f.split('_')[1] for f in files_list]
fig, axs = plt.subplots(len(layer_names), 2, figsize=(10, 5 * len(layer_names)))
layer_names = sorted(layer_names, key=lambda x: int(x.split('_')[1]))
# take only unique layer names
layer_names = list(dict.fromkeys(layer_names))
for i,layer_name in enumerate(layer_names[10:]):
    correct_corr = np.load(joinpath(corr_results_dir, f"{layer_name}_correct_avg_correlation.npy"))
    incorrect_corr = np.load(joinpath(corr_results_dir, f"{layer_name}_incorrect_avg_correlation.npy"))
    sns.heatmap(correct_corr, ax=axs[i, 0],

                    cmap='viridis', cbar=True, vmin=-1, vmax=1)
    axs[i, 0].set_title(f'Correct Layer Correlation - {layer_name}')
    sns.heatmap(incorrect_corr, ax=axs[i, 1],
                    cmap='viridis', cbar=True, vmin=-1, vmax=1)
    axs[i, 1].set_title(f'Incorrect Layer Correlation - {layer_name}')
    print(f"Layer {layer_name} plotted")

# %%
corr_results_dir = "/home/szymon/code/PhD/snns_adversarial_benchmark/avg_corr_results_avg_sampling_100"
files_list = os.listdir(corr_results_dir)
layer_names = [f.split('_')[0] + "_" + f.split('_')[1] for f in files_list]
fig, axs = plt.subplots(len(layer_names[10:]), 2, figsize=(10, 5 * len(layer_names)))
layer_names = sorted(layer_names, key=lambda x: int(x.split('_')[1]))
# take only unique layer names
layer_names = list(dict.fromkeys(layer_names))
for i,layer_name in enumerate(layer_names[10:]):
    correct_corr = np.load(joinpath(corr_results_dir, f"{layer_name}_correct_avg_correlation.npy"))
    incorrect_corr = np.load(joinpath(corr_results_dir, f"{layer_name}_incorrect_avg_correlation.npy"))
    sns.heatmap(correct_corr, ax=axs[i, 0],

                    cmap='viridis', cbar=True, vmin=-1, vmax=1)
    axs[i, 0].set_title(f'Correct Layer Correlation - {layer_name}')
    sns.heatmap(incorrect_corr, ax=axs[i, 1],
                    cmap='viridis', cbar=True, vmin=-1, vmax=1)
    axs[i, 1].set_title(f'Incorrect Layer Correlation - {layer_name}')
    print(f"Layer {layer_name} plotted")
